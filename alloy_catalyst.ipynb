# %% [markdown]
# # Import libraries

# %%
import pandas as pd

# %% [markdown]
# # Load data
#
# The dataset is made available by [Jeremy Hitt](https://github.com/jlhitt1993/LearningCatalyst) and is also analyzed in his [paper](https://doi.org/10.1021/acssuschemeng.2c05170).
#
# `data`: The experimental dataset
#
# `element_data`: Additional textbook data on individual elements.

# %%
data = pd.read_excel('Db with no amine.xlsx')
element_data = pd.read_excel("Database of elements.xlsx")

# %%
data
# Out:
#        Sample ID  Percent A  Percent B  Percent C  Onset potential H2 Ag/AgCl  \
# 0     Ni0Pt10Pd0        0.0        1.0        0.0                       -0.10
# 1      Ni0Pt9Pd1        0.0        0.9        0.1                       -0.25
# 2      Ni0Pt8Pd2        0.0        0.8        0.2                       -0.20
# 3      Ni0Pt7Pd3        0.0        0.7        0.3                       -0.15
# 4      Ni0Pt6Pd4        0.0        0.6        0.4                       -0.20
# ...          ...        ...        ...        ...                         ...
# 1579   Sn8Pd1Pt1        0.8        0.1        0.1                        0.00
# 1580   Sn8Pd0Pt2        0.8        0.0        0.2                        0.90
# 1581   Sn9Pd1Pt0        0.9        0.1        0.0                        0.90
# 1582   Sn9Pd0Pt1        0.9        0.0        0.1                        0.90
# 1583  Sn10Pd0Pt0        1.0        0.0        0.0                        0.90
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1584 entries, 0 to 1583
# Data columns (total 45 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Sample ID                    1584 non-null   object
#  1   Percent A                    1584 non-null   float64
#  2   Percent B                    1584 non-null   float64
#  3   Percent C                    1584 non-null   float64
#  4   Onset potential H2 Ag/AgCl   1584 non-null   float64
#  5   Element A atomic #           1584 non-null   int64
#  6   Element B atomic #           1584 non-null   int64
#  7   Element C atomic #           1584 non-null   int64
#  8   Electronegativity of A       1584 non-null   float64
#  9   Electronegativity of B       1584 non-null   float64
#  10  Electronegativity of C       1584 non-null   float64
#  11  Reduction potential of A     1584 non-null   float64
# ...

# %%
element_data
# Out:
#    Element  Atomic #  Electronegativity  Reduction potential  Periodic group  \
# 0       Ag        47               1.93                0.790              11
# 1       Au        79               2.54                1.360              11
# 2       Co        27               1.88               -0.277               9
# 3       Cu        29               1.90                0.159              11
# 4       Fe        26               1.83               -0.037               8
# 5       Hg        80               2.00                0.796              12
# 6       Ni        28               1.91               -0.230              10
# 7       Pb        82               2.33               -0.130              14
# 8       Pd        46               2.20                0.600              10
# 9       Pt        78               2.28                0.730              10
# 10      Rh        45               2.28                0.760               9
# ...

# %%
element_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 14 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Element                     12 non-null     object
#  1   Atomic #                    12 non-null     int64
#  2   Electronegativity           12 non-null     float64
#  3   Reduction potential         12 non-null     float64
#  4   Periodic group              12 non-null     int64
#  5   Electron configuration      12 non-null     object
#  6   Ionization energy           12 non-null     float64
#  7   Work function               12 non-null     float64
#  8   Crystal structure           12 non-null     object
#  9   Lattice spacing             12 non-null     float64
#  10  H binding energy(eV)        12 non-null     float64
#  11  M-O bond energy             12 non-null     float64
#  12  OH binding energy(eV)       12 non-null     float64
# ...
